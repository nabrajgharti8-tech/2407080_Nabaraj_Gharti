# %% [markdown]
# <a href="https://colab.research.google.com/github/nabrajgharti8-tech/2407080_Nabaraj_Gharti_AI/blob/main/Worksheet_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Daily time (in hours): [study, entertainment, sleep]
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

low_study = []
moderate_study = []
high_study = []

for study, entertainment, sleep in time_data:
    if study < 3:
        low_study.append((study))
    elif 3 <= study <= 5:
        moderate_study.append((study))
    elif study > 5:
        high_study.append((study))

print("Low study hours: ", low_study)
print("Moderate study hours: ", moderate_study)
print("High study hours: ", high_study)
# Out:
# Low study hours:  [2.5, 1.5, 2.0, 2.5]
# Moderate study hours:  [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High study hours:  [5.5, 6.0]

# %%
low_count = 0
for s in low_study:
    low_count += 1
print("Number of days with low study time: ", low_count)

moderate_count = 0
for m in moderate_study:
    moderate_count += 1
print("Number of days with moderate study time: ", moderate_count)

high_count = 0
for h in high_study:
    high_count += 1
print("Number of days with high study time: ", high_count)

# print(f"Number of days with low study time: {len(low_study)}")
# print(f"Number of days with moderate study time: {len(moderate_study)}")
# print(f"Number of days with high study time: {len(high_study)}")
# Out:
# Number of days with low study time:  4
# Number of days with moderate study time:  9
# Number of days with high study time:  2

# %%
study_minutes = []
for study, entertainment, sleep in time_data:
    minutes = study * 60
    study_minutes.append(minutes)

print("Study hours in minutes:",study_minutes)
# Out:
# Study hours in minutes: [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %%
study_hours = []
entertainment_hours = []
sleep_hours = []

for study, entertainment, sleep in time_data:
    study_hours.append(study)
    entertainment_hours.append(entertainment)
    sleep_hours.append(sleep)

sh_sum = 0
for sh in study_hours:
    sh_sum += sh
sh_avg = sh_sum/len(study_hours)

eh_sum = 0
for eh in entertainment_hours:
    eh_sum += eh
eh_avg = eh_sum/len(entertainment_hours)

sl_sum = 0
for sl in sleep_hours:
    sl_sum += sl
sl_avg = sl_sum/len(sleep_hours)

print(sh_avg)
print(eh_avg)
print(sl_avg)
# Out:
# 3.7
# 2.5
# 7.166666666666667

# %%
import matplotlib.pyplot as plt

study_hours = []
sleep_hours = []

for study, entertainment, sleep in time_data:
    study_hours.append(study)
    sleep_hours.append(sleep)

plt.scatter(study_hours, sleep_hours, c='green')

plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.title("Study Hours vs Sleep Hours")

plt.show()

# %%
def sum_nested_list(nested_list):
    """
    Calculate the sum of all numbers in a nested list.
    This function takes a list that may contain integers and other nested lists.
    It recursively traverses the list and sums all the integers, no matter how deeply
    nested they are.

    Args:
        nested_list (list): A list that may contain integers or other lists of integers.

    Returns:
        int: The total sum of all integers in the nested list, including those in sublists.

    Example:
    >>> sum_nested_list([1, [2, [3, 4], 5], 6, [7, 8]])
    36
    >>> sum_nested_list([1, [2, 3], [4, [5]]])
    15
    """
    total = 0
    for element in nested_list:
        if isinstance(element, list):  # Check if the element is a list
            total += sum_nested_list(element)  # Recursively sum the nested list
        else:
            total += element  # Add the number to the total
    return total

nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
result = sum_nested_list(nested_list)
print("Total Sum: ", result)
# Out:
# Total Sum:  36

# %%
def generate_permutations(s):
    """
    This function takes a string and recursively generates all unique permutations of the string.

    Args:
        s (str): Input String

    Returns:
        list: A list of unique permutations of the string.
    """

    if len(s) <= 1:
        return s

    permutations = []

    for i, char in enumerate(s):
        remaining = s[:i] + s[i+1:]
        for p in generate_permutations(remaining):
            permutations.append(char + p)

    return list(set(permutations))
print(generate_permutations("abc"))
print(generate_permutations("aab"))
# Out:
# ['cba', 'bca', 'cab', 'acb', 'bac', 'abc']
# ['aba', 'aab', 'baa']

# %%
def calculate_directory_size(directory):
    """
    This function recursively calculates the total size of a directory

    Args:
        directory (dict): Dictionary representing files and subdirectories

    Returns:
        int: Total size of directory including all nested files/sudirectories.
    """

    total_size = 0
    for key, value in directory.items():
        if isinstance(value, dict):
            total_size += calculate_directory_size(value)
        else:
            total_size += value
    return total_size

# Sample directory structure
directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}

total_size = calculate_directory_size(directory_structure)
print("Total directory size:", total_size, "KB")
# Out:
# Total directory size: 1400 KB

# %%
def min_coins(coins, amount):
    """
    Finds the minimum number of coins needed to make up a given amount using dynamic
    programming (tabulation).

    Parameters:
        coins (list of int): Available coin denominations.
        amount (int): Target amount to make change for.

    Returns:
        int: Minimum number of coins needed. Returns -1 if amount cannot be made.

    Example:
    >>> min_coins([1, 2, 5], 11)
    3
    >>> min_coins([2], 3)
    -1
    """
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0

    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)


    return dp[amount] if dp[amount] != float('inf') else -1

print(min_coins([1,2,5],11))
print(min_coins([5,5,1],3))
# Out:
# 3
# 3

# %%
def longest_common_subsequence(s1, s2):
    n = len(s1)
    m = len(s2)
    '''
    Finds the longest common subsequence in the given strings using dynamic programming.

    Parameters:
        s1 (strings): First string
        s2 (stirngs): Second string

    Returns:
        int: The length longest common subsequence between two strings.
    '''

    memo = {}

    def rec(i, j):

        if i == 0 or j == 0:
            return 0

        if (i, j) in memo:
            return memo[(i,j)]

        if s1[i-1] == s2[j-1]:
            memo[(i,j)] = 1 + rec(i-1,j-1)

        else:
            memo[(i,j)] = max(rec(i-1, j), rec(i, j-1))

        return memo[(i,j)]

    return rec(len(s1), len(s2))

print(longest_common_subsequence("abcd", "abc"))
# Out:
# 3

# %%
def knapsack_memo(weights, values, capacity):
    n = len(weights)
    memo = {}

    def rec(i, j):
        if i == 0 or j == 0:
            return 0

        if (i, j) in memo:
            return memo[(i,j)]

        if weights[i-1] <= j:
            memo[(i,j)] = max(rec(i-1,j), values[i-1]+rec(i-1, j - weights[i-1]))

        else:
            memo[(i,j)] = rec(i-1, j)

        return memo[(i,j)]

    return rec(n, capacity)

weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7

print(knapsack_memo(weights, values, capacity))
# Out:
# 9
